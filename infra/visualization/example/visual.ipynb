# %%
from visualization import OECTPlotter

plotter = OECTPlotter('/home/lidonghaowsl/develop_win/hdd/data/Stability_PS/raw/#20250804007-6-稳定性测试-test_20250815134210_dfc249c3.h5')

# %%
# # 6个核心功能一行代码调用
# fig = plotter.plot_transfer_single(2,log_scale=False)
# fig = plotter.plot_transfer_single(2,log_scale=True)

# %%
# fig = plotter.plot_transfer_multiple([0, 1,10,100,1000,2000,3000,4000,5000], log_scale=False,figsize=(8,6))
fig = plotter.plot_transfer_multiple([0, 1,10,100,1000,2000,3000,4000,5000], log_scale=True,figsize=(8,6))

# %%
# fig = plotter.plot_transfer_evolution(log_scale=False)

# %%
fig = plotter.plot_transient_all(figsize=(8,6))
# Out:
# 2025-09-02 02:13:06 - experiment.repositories.batch_hdf5_repository - WARNING - batch_hdf5_repository.py:694 - 正在加载所有transient数据，这可能会消耗大量内存

# %%
# plotter.create_transfer_video_parallel(
#     save_path="evolution_linear.mp4",
#     n_workers=48,
#     fps=30,
#     figsize=(8, 6),
#     layout='linear'
# )

# %%
# plotter.create_transfer_video_parallel(
#     save_path="evolution_dual.mp4",
#     n_workers=48,
#     fps=30,
#     figsize=(8, 6),
#     layout='dual'
# )

# %%
# fig = plotter.plot_transient_single(0, time_range=(5, 10))

# %%
fig = plotter.plot_transient_single(1, time_range=(5, 6),figsize=(8, 6))

# %%
fig = plotter.plot_transient_single(1000, time_range=(5, 6),figsize=(8, 6))

# %%
# fig = plotter.plot_transient_single(2000, time_range=(5, 6),figsize=(8, 6))

# %%
# fig = plotter.plot_transient_single(4999, time_range=(5, 6),figsize=(8, 6))
