# %%
from features_version.batch_create_feature import batch_create_features
from features_version.v1_feature import v1_feature
import logging
from logger_config import log_manager, get_module_logger
log_manager.set_levels(
    file_level=logging.WARNING,    # 文件记录详细信息
    console_level=logging.WARNING   # 控制台只显示重要信息
)
logger = get_module_logger()# 简洁模式 - v1_feature和batch_create_features都会使用简洁输出
batch_create_features("/mnt/d/UserData/lidonghaowsl/data/Stability_PS/raw", "/mnt/d/UserData/lidonghaowsl/data/Stability_PS/features", v1_feature)
# Out:
# 处理: #20250804007-1-稳定性测试-test_20250815134210_290e653d....:   0%|          | 0/22 [00:00<?, ?文件/s]2025-08-31 17:58:53 - experiment.repositories.batch_hdf5_repository - WARNING - batch_hdf5_repository.py:616 - 正在加载所有transfer数据，这可能会消耗大量内存
# 处理: #20250804007-2-稳定性测试-test_20250815134210_403dce1b....:   5%|▍         | 1/22 [00:08<03:06,  8.89s/文件, 成功=1, 失败=0, 进度=1/22]2025-08-31 17:59:02 - experiment.repositories.batch_hdf5_repository - WARNING - batch_hdf5_repository.py:616 - 正在加载所有transfer数据，这可能会消耗大量内存
# 处理: #20250804007-3-稳定性测试-test_20250815134210_6b44fb0e....:   9%|▉         | 2/22 [00:17<02:58,  8.92s/文件, 成功=2, 失败=0, 进度=2/22]2025-08-31 17:59:11 - experiment.repositories.batch_hdf5_repository - WARNING - batch_hdf5_repository.py:616 - 正在加载所有transfer数据，这可能会消耗大量内存
# 处理: #20250804007-4-稳定性测试-test_20250815134210_480af66c....:  14%|█▎        | 3/22 [00:26<02:47,  8.83s/文件, 成功=3, 失败=0, 进度=3/22]2025-08-31 17:59:19 - experiment.repositories.batch_hdf5_repository - WARNING - batch_hdf5_repository.py:616 - 正在加载所有transfer数据，这可能会消耗大量内存
# 处理: #20250804007-5-稳定性测试-test_20250815134210_e515c701....:  18%|█▊        | 4/22 [00:35<02:40,  8.89s/文件, 成功=4, 失败=0, 进度=4/22]2025-08-31 17:59:28 - experiment.repositories.batch_hdf5_repository - WARNING - batch_hdf5_repository.py:616 - 正在加载所有transfer数据，这可能会消耗大量内存
# 处理: #20250804007-6-稳定性测试-test_20250815134210_dfc249c3....:  23%|██▎       | 5/22 [00:44<02:31,  8.91s/文件, 成功=5, 失败=0, 进度=5/22]2025-08-31 17:59:37 - experiment.repositories.batch_hdf5_repository - WARNING - batch_hdf5_repository.py:616 - 正在加载所有transfer数据，这可能会消耗大量内存
# 处理: #20250804008-1-稳定性测试-test_20250815134210_635cd027....:  27%|██▋       | 6/22 [00:53<02:22,  8.90s/文件, 成功=6, 失败=0, 进度=6/22]2025-08-31 17:59:46 - experiment.repositories.batch_hdf5_repository - WARNING - batch_hdf5_repository.py:616 - 正在加载所有transfer数据，这可能会消耗大量内存
# 处理: #20250804008-2-稳定性测试-test_20250815134210_7a2f9949....:  32%|███▏      | 7/22 [01:02<02:15,  9.03s/文件, 成功=7, 失败=0, 进度=7/22]2025-08-31 17:59:55 - experiment.repositories.batch_hdf5_repository - WARNING - batch_hdf5_repository.py:616 - 正在加载所有transfer数据，这可能会消耗大量内存
# 处理: #20250804008-3-稳定性测试-test_20250815134211_3fa6110a....:  36%|███▋      | 8/22 [01:11<02:05,  8.99s/文件, 成功=8, 失败=0, 进度=8/22]2025-08-31 18:00:04 - experiment.repositories.batch_hdf5_repository - WARNING - batch_hdf5_repository.py:616 - 正在加载所有transfer数据，这可能会消耗大量内存
# 处理: #20250804008-4-稳定性测试-test_20250815134211_d10f52a5....:  41%|████      | 9/22 [01:20<01:56,  8.93s/文件, 成功=9, 失败=0, 进度=9/22]2025-08-31 18:00:13 - experiment.repositories.batch_hdf5_repository - WARNING - batch_hdf5_repository.py:616 - 正在加载所有transfer数据，这可能会消耗大量内存
# 处理: #20250804008-5-稳定性测试-test_20250815134211_052b811a....:  45%|████▌     | 10/22 [01:29<01:46,  8.91s/文件, 成功=10, 失败=0, 进度=10/22]2025-08-31 18:00:22 - experiment.repositories.batch_hdf5_repository - WARNING - batch_hdf5_repository.py:616 - 正在加载所有transfer数据，这可能会消耗大量内存
# 处理: #20250804008-6-稳定性测试-test_20250815134211_9ee6456d....:  50%|█████     | 11/22 [01:38<01:37,  8.88s/文件, 成功=11, 失败=0, 进度=11/22]2025-08-31 18:00:31 - experiment.repositories.batch_hdf5_repository - WARNING - batch_hdf5_repository.py:616 - 正在加载所有transfer数据，这可能会消耗大量内存
# 处理: #20250825001-1-稳定性测试-test_20250825141031_e4bcd149....:  55%|█████▍    | 12/22 [01:46<01:28,  8.87s/文件, 成功=12, 失败=0, 进度=12/22]2025-08-31 18:00:40 - experiment.repositories.batch_hdf5_repository - WARNING - batch_hdf5_repository.py:616 - 正在加载所有transfer数据，这可能会消耗大量内存
# 处理: #20250825001-2-稳定性测试-test_20250825141031_a9781db8....:  59%|█████▉    | 13/22 [01:55<01:18,  8.69s/文件, 成功=13, 失败=0, 进度=13/22]2025-08-31 18:00:48 - experiment.repositories.batch_hdf5_repository - WARNING - batch_hdf5_repository.py:616 - 正在加载所有transfer数据，这可能会消耗大量内存
# 处理: #20250825001-3-稳定性测试-test_20250825141031_c52a87bd....:  64%|██████▎   | 14/22 [02:03<01:08,  8.58s/文件, 成功=14, 失败=0, 进度=14/22]2025-08-31 18:00:56 - experiment.repositories.batch_hdf5_repository - WARNING - batch_hdf5_repository.py:616 - 正在加载所有transfer数据，这可能会消耗大量内存
# 处理: #20250825001-4-稳定性测试-test_20250825141031_4755d34f....:  68%|██████▊   | 15/22 [02:11<00:59,  8.49s/文件, 成功=15, 失败=0, 进度=15/22]2025-08-31 18:01:05 - experiment.repositories.batch_hdf5_repository - WARNING - batch_hdf5_repository.py:616 - 正在加载所有transfer数据，这可能会消耗大量内存
# 处理: #20250825001-5-稳定性测试-test_20250825141031_718ad63f....:  73%|███████▎  | 16/22 [02:19<00:50,  8.41s/文件, 成功=16, 失败=0, 进度=16/22]2025-08-31 18:01:13 - experiment.repositories.batch_hdf5_repository - WARNING - batch_hdf5_repository.py:616 - 正在加载所有transfer数据，这可能会消耗大量内存
# 处理: #20250825002-1-稳定性测试-test_20250825141031_8bc7ad8e....:  77%|███████▋  | 17/22 [02:28<00:42,  8.41s/文件, 成功=17, 失败=0, 进度=17/22]2025-08-31 18:01:21 - experiment.repositories.batch_hdf5_repository - WARNING - batch_hdf5_repository.py:616 - 正在加载所有transfer数据，这可能会消耗大量内存
# 处理: #20250825002-2-稳定性测试-test_20250825141031_0d386eaa....:  82%|████████▏ | 18/22 [02:36<00:33,  8.39s/文件, 成功=18, 失败=0, 进度=18/22]2025-08-31 18:01:30 - experiment.repositories.batch_hdf5_repository - WARNING - batch_hdf5_repository.py:616 - 正在加载所有transfer数据，这可能会消耗大量内存
# 处理: #20250825002-3-稳定性测试-test_20250825141031_25b99663....:  86%|████████▋ | 19/22 [02:45<00:25,  8.37s/文件, 成功=19, 失败=0, 进度=19/22]2025-08-31 18:01:38 - experiment.repositories.batch_hdf5_repository - WARNING - batch_hdf5_repository.py:616 - 正在加载所有transfer数据，这可能会消耗大量内存
# 处理: #20250825002-5-稳定性测试-test_20250825141032_78cd79a4....:  91%|█████████ | 20/22 [02:53<00:16,  8.35s/文件, 成功=20, 失败=0, 进度=20/22]2025-08-31 18:01:46 - experiment.repositories.batch_hdf5_repository - WARNING - batch_hdf5_repository.py:616 - 正在加载所有transfer数据，这可能会消耗大量内存
# 处理: #20250825002-6-稳定性测试-test_20250825141032_05759654....:  95%|█████████▌| 21/22 [03:01<00:08,  8.32s/文件, 成功=21, 失败=0, 进度=21/22]2025-08-31 18:01:54 - experiment.repositories.batch_hdf5_repository - WARNING - batch_hdf5_repository.py:616 - 正在加载所有transfer数据，这可能会消耗大量内存
# 处理: #20250825002-6-稳定性测试-test_20250825141032_05759654....: 100%|██████████| 22/22 [03:09<00:00,  8.63s/文件, 成功=22, 失败=0, 进度=22/22]
# === 批量处理完成 ===
# ✅ 成功: 22/22 个文件

# %%
# from features_version.v1_feature import v1_feature

# print('=== 运行v1 ===')
# v1_file = v1_feature('/mnt/d/UserData/lidonghaowsl/data/Stability_PS/#20250804007-4-稳定性测试-test_20250815134210_480af66c.h5')

# print(f'\n最终文件: {v1_file}')

# %% [markdown]
# # 加载特征数据

# %%
import matplotlib.pyplot as plt
from chip_feature_plotter import ChipFeaturePlotter, plot_chip_feature

# 设置matplotlib支持中文显示
plt.rcParams['font.sans-serif'] = ['SimHei', 'DejaVu Sans']
plt.rcParams['axes.unicode_minus'] = False
plotter = ChipFeaturePlotter("/mnt/d/UserData/lidonghaowsl/data/Stability_PS/features/")

# 查看所有可用芯片
dir_stats = plotter.batch_manager.get_directory_statistics()
print(f"总文件数: {dir_stats['total_files']}")
print(f"芯片分布: {dir_stats['chip_distribution']}")
# Out:
# 总文件数: 22
# 芯片分布: {'#20250804007': 6, '#20250804008': 6, '#20250825001': 5, '#20250825002': 5}

# %%
# 为每个芯片绘制相同特征
available_chips = list(dir_stats['chip_distribution'].keys())

# %%
# 找到所有芯片的共同特征
common_features = None
for chip_id in available_chips:
    chip_features = plotter.list_chip_features(chip_id)
    if common_features is None:
        common_features = set(chip_features)
    else:
        common_features &= set(chip_features)

common_features = list(common_features)
print(f"\n所有芯片的共同特征 ({len(common_features)} 个): {common_features}")
# Out:
# 所有芯片的共同特征 (15 个): ['Von_forward', 'Von_reverse_Vg', 'Von_reverse_Id', 'absI_max_raw_Vg', 'Von_reverse', 'absI_max_raw', 'absgm_max_forward_Id', 'absgm_max_forward', 'absgm_max_reverse_Vg', 'absgm_max_reverse', 'absgm_max_forward_Vg', 'absgm_max_reverse_Id', 'absI_max_raw_Id', 'Von_forward_Vg', 'Von_forward_Id']

# %% [markdown]
# # absI_max_raw

# %%
    
feature_name = 'absI_max_raw'
chip_id = '20250825001'
fig = plotter.plot_chip_feature(
    chip_id=chip_id,
    feature_name=feature_name,
    skip_points=0,
    normalize_to_first=False,
    markersize=0,
    figsize=(8, 6),
)
# Out:
# 2025-08-31 18:52:10 - chip_feature_plotter - INFO - chip_feature_plotter.py:88 - 开始绘制芯片 20250825001 的特征 absI_max_raw
# 2025-08-31 18:52:10 - chip_feature_plotter - INFO - chip_feature_plotter.py:96 - 找到 5 个特征文件
# 2025-08-31 18:52:11 - chip_feature_plotter - INFO - chip_feature_plotter.py:138 - 成功加载 5 个设备的数据
# 2025-08-31 18:52:11 - chip_feature_plotter - INFO - chip_feature_plotter.py:234 - 数据处理摘要:
# 2025-08-31 18:52:11 - chip_feature_plotter - INFO - chip_feature_plotter.py:236 -   设备 1: 5001 -> 5001 点
# 2025-08-31 18:52:11 - chip_feature_plotter - INFO - chip_feature_plotter.py:238 -     数据范围: 1.43e-06 ~ 5.60e-04
# 2025-08-31 18:52:11 - chip_feature_plotter - INFO - chip_feature_plotter.py:236 -   设备 2: 5001 -> 5001 点
# 2025-08-31 18:52:11 - chip_feature_plotter - INFO - chip_feature_plotter.py:238 -     数据范围: 2.60e-06 ~ 8.12e-04
# 2025-08-31 18:52:11 - chip_feature_plotter - INFO - chip_feature_plotter.py:236 -   设备 3: 5001 -> 5001 点
# 2025-08-31 18:52:11 - chip_feature_plotter - INFO - chip_feature_plotter.py:238 -     数据范围: 8.66e-06 ~ 5.35e-04
# 2025-08-31 18:52:11 - chip_feature_plotter - INFO - chip_feature_plotter.py:236 -   设备 4: 5001 -> 5001 点
# 2025-08-31 18:52:11 - chip_feature_plotter - INFO - chip_feature_plotter.py:238 -     数据范围: 7.79e-05 ~ 1.32e-03
# 2025-08-31 18:52:11 - chip_feature_plotter - INFO - chip_feature_plotter.py:236 -   设备 5: 5001 -> 5001 点
# 2025-08-31 18:52:11 - chip_feature_plotter - INFO - chip_feature_plotter.py:238 -     数据范围: 4.45e-06 ~ 1.34e-03

# %%
fig = plotter.plot_chip_feature(
    chip_id=chip_id,
    feature_name=feature_name,
    skip_points=0,
    normalize_to_first=True,
    markersize=0,
    figsize=(8, 6),
)

# %%
fig = plotter.plot_chip_feature(
    chip_id=chip_id,
    feature_name=feature_name,
    skip_points=1,
    normalize_to_first=False,
    markersize=0,
    figsize=(8, 6),
)
# Out:
# 2025-08-31 18:53:18 - chip_feature_plotter - INFO - chip_feature_plotter.py:88 - 开始绘制芯片 20250825001 的特征 absI_max_raw
# 2025-08-31 18:53:18 - chip_feature_plotter - INFO - chip_feature_plotter.py:96 - 找到 5 个特征文件
# 2025-08-31 18:53:18 - chip_feature_plotter - INFO - chip_feature_plotter.py:138 - 成功加载 5 个设备的数据
# 2025-08-31 18:53:18 - chip_feature_plotter - INFO - chip_feature_plotter.py:234 - 数据处理摘要:
# 2025-08-31 18:53:18 - chip_feature_plotter - INFO - chip_feature_plotter.py:236 -   设备 1: 5001 -> 5000 点
# 2025-08-31 18:53:18 - chip_feature_plotter - INFO - chip_feature_plotter.py:238 -     数据范围: 1.43e-06 ~ 5.56e-04
# 2025-08-31 18:53:18 - chip_feature_plotter - INFO - chip_feature_plotter.py:236 -   设备 2: 5001 -> 5000 点
# 2025-08-31 18:53:18 - chip_feature_plotter - INFO - chip_feature_plotter.py:238 -     数据范围: 2.60e-06 ~ 7.62e-04
# 2025-08-31 18:53:18 - chip_feature_plotter - INFO - chip_feature_plotter.py:236 -   设备 3: 5001 -> 5000 点
# 2025-08-31 18:53:18 - chip_feature_plotter - INFO - chip_feature_plotter.py:238 -     数据范围: 8.66e-06 ~ 4.82e-04
# 2025-08-31 18:53:18 - chip_feature_plotter - INFO - chip_feature_plotter.py:236 -   设备 4: 5001 -> 5000 点
# 2025-08-31 18:53:18 - chip_feature_plotter - INFO - chip_feature_plotter.py:238 -     数据范围: 7.79e-05 ~ 1.32e-03
# 2025-08-31 18:53:18 - chip_feature_plotter - INFO - chip_feature_plotter.py:236 -   设备 5: 5001 -> 5000 点
# 2025-08-31 18:53:18 - chip_feature_plotter - INFO - chip_feature_plotter.py:238 -     数据范围: 4.45e-06 ~ 1.34e-03

# %%
fig = plotter.plot_chip_feature(
    chip_id=chip_id,
    feature_name=feature_name,
    skip_points=1,
    normalize_to_first=True,
    markersize=0,
    figsize=(8, 6),
)

# %%
fig = plotter.plot_chip_feature(
    chip_id=chip_id,
    feature_name=feature_name,
    skip_points=2,
    normalize_to_first=True,
    markersize=0,
    figsize=(8, 6),
)

# %%
fig = plotter.plot_chip_feature(
    chip_id=chip_id,
    feature_name=feature_name,
    skip_points=5,
    normalize_to_first=False,
    markersize=0,
    figsize=(8, 6),
)
# Out:
# 2025-08-31 18:56:11 - chip_feature_plotter - INFO - chip_feature_plotter.py:88 - 开始绘制芯片 20250825001 的特征 absI_max_raw
# 2025-08-31 18:56:11 - chip_feature_plotter - INFO - chip_feature_plotter.py:96 - 找到 5 个特征文件
# 2025-08-31 18:56:11 - chip_feature_plotter - INFO - chip_feature_plotter.py:138 - 成功加载 5 个设备的数据
# 2025-08-31 18:56:11 - chip_feature_plotter - INFO - chip_feature_plotter.py:234 - 数据处理摘要:
# 2025-08-31 18:56:11 - chip_feature_plotter - INFO - chip_feature_plotter.py:236 -   设备 1: 5001 -> 4996 点
# 2025-08-31 18:56:11 - chip_feature_plotter - INFO - chip_feature_plotter.py:238 -     数据范围: 1.43e-06 ~ 5.51e-04
# 2025-08-31 18:56:11 - chip_feature_plotter - INFO - chip_feature_plotter.py:236 -   设备 2: 5001 -> 4996 点
# 2025-08-31 18:56:11 - chip_feature_plotter - INFO - chip_feature_plotter.py:238 -     数据范围: 2.60e-06 ~ 2.05e-04
# 2025-08-31 18:56:11 - chip_feature_plotter - INFO - chip_feature_plotter.py:236 -   设备 3: 5001 -> 4996 点
# 2025-08-31 18:56:11 - chip_feature_plotter - INFO - chip_feature_plotter.py:238 -     数据范围: 8.66e-06 ~ 4.77e-04
# 2025-08-31 18:56:11 - chip_feature_plotter - INFO - chip_feature_plotter.py:236 -   设备 4: 5001 -> 4996 点
# 2025-08-31 18:56:11 - chip_feature_plotter - INFO - chip_feature_plotter.py:238 -     数据范围: 7.79e-05 ~ 1.22e-03
# 2025-08-31 18:56:11 - chip_feature_plotter - INFO - chip_feature_plotter.py:236 -   设备 5: 5001 -> 4996 点
# 2025-08-31 18:56:11 - chip_feature_plotter - INFO - chip_feature_plotter.py:238 -     数据范围: 4.45e-06 ~ 1.31e-03

# %%
fig = plotter.plot_chip_feature(
    chip_id=chip_id,
    feature_name=feature_name,
    skip_points=5,
    normalize_to_first=True,
    markersize=0,
    figsize=(8, 6),
)

# %%
fig = plotter.plot_chip_feature(
    chip_id=chip_id,
    feature_name=feature_name,
    skip_points=10,
    normalize_to_first=True,
    markersize=0,
    figsize=(8, 6),
)

# %%
fig = plotter.plot_chip_feature(
    chip_id=chip_id,
    feature_name=feature_name,
    skip_points=20,
    normalize_to_first=True,
    markersize=0,
    figsize=(8, 6),
)

# %%
fig = plotter.plot_chip_feature(
    chip_id=chip_id,
    feature_name=feature_name,
    skip_points=50,
    normalize_to_first=True,
    markersize=0,
    figsize=(8, 6),
)

# %%
fig = plotter.plot_chip_feature(
    chip_id=chip_id,
    feature_name=feature_name,
    skip_points=100,
    normalize_to_first=True,
    markersize=0,
    figsize=(8, 6),
)

# %%
fig = plotter.plot_chip_feature(
    chip_id=chip_id,
    feature_name=feature_name,
    skip_points=200,
    normalize_to_first=True,
    markersize=0,
    figsize=(8, 6),
)

# %%
fig = plotter.plot_chip_feature(
    chip_id=chip_id,
    feature_name=feature_name,
    skip_points=500,
    normalize_to_first=True,
    markersize=0,
    figsize=(8, 6),
)

# %%
fig = plotter.plot_chip_feature(
    chip_id=chip_id,
    feature_name=feature_name,
    skip_points=1000,
    normalize_to_first=False,
    markersize=0,
    figsize=(8, 6),
)

# %%
fig = plotter.plot_chip_feature(
    chip_id=chip_id,
    feature_name=feature_name,
    skip_points=1000,
    normalize_to_first=True,
    markersize=0,
    figsize=(8, 6),
)

# %% [markdown]
# # absgm_max_forward

# %%
    
feature_name = 'absgm_max_forward'
chip_id = '20250825001'
fig = plotter.plot_chip_feature(
    chip_id=chip_id,
    feature_name=feature_name,
    skip_points=0,
    normalize_to_first=False,
    markersize=0,
    figsize=(8, 6),
)
# Out:
# 2025-08-31 19:35:28 - chip_feature_plotter - INFO - chip_feature_plotter.py:88 - 开始绘制芯片 20250825001 的特征 absgm_max_forward
# 2025-08-31 19:35:28 - chip_feature_plotter - INFO - chip_feature_plotter.py:96 - 找到 5 个特征文件
# 2025-08-31 19:35:28 - chip_feature_plotter - INFO - chip_feature_plotter.py:138 - 成功加载 5 个设备的数据
# 2025-08-31 19:35:28 - chip_feature_plotter - INFO - chip_feature_plotter.py:234 - 数据处理摘要:
# 2025-08-31 19:35:28 - chip_feature_plotter - INFO - chip_feature_plotter.py:236 -   设备 1: 5001 -> 5001 点
# 2025-08-31 19:35:28 - chip_feature_plotter - INFO - chip_feature_plotter.py:238 -     数据范围: 4.91e-05 ~ 2.52e-03
# 2025-08-31 19:35:28 - chip_feature_plotter - INFO - chip_feature_plotter.py:236 -   设备 2: 5001 -> 5001 点
# 2025-08-31 19:35:28 - chip_feature_plotter - INFO - chip_feature_plotter.py:238 -     数据范围: 4.83e-05 ~ 2.59e-03
# 2025-08-31 19:35:28 - chip_feature_plotter - INFO - chip_feature_plotter.py:236 -   设备 3: 5001 -> 5001 点
# 2025-08-31 19:35:28 - chip_feature_plotter - INFO - chip_feature_plotter.py:238 -     数据范围: 6.16e-05 ~ 1.84e-03
# 2025-08-31 19:35:28 - chip_feature_plotter - INFO - chip_feature_plotter.py:236 -   设备 4: 5001 -> 5001 点
# 2025-08-31 19:35:28 - chip_feature_plotter - INFO - chip_feature_plotter.py:238 -     数据范围: 3.85e-04 ~ 4.06e-03
# 2025-08-31 19:35:28 - chip_feature_plotter - INFO - chip_feature_plotter.py:236 -   设备 5: 5001 -> 5001 点
# 2025-08-31 19:35:28 - chip_feature_plotter - INFO - chip_feature_plotter.py:238 -     数据范围: 4.47e-05 ~ 6.47e-03

# %%
fig = plotter.plot_chip_feature(
    chip_id=chip_id,
    feature_name=feature_name,
    skip_points=0,
    normalize_to_first=True,
    markersize=0,
    figsize=(8, 6),
)

# %%
fig = plotter.plot_chip_feature(
    chip_id=chip_id,
    feature_name=feature_name,
    skip_points=1,
    normalize_to_first=False,
    markersize=0,
    figsize=(8, 6),
)

# %%
fig = plotter.plot_chip_feature(
    chip_id=chip_id,
    feature_name=feature_name,
    skip_points=1,
    normalize_to_first=True,
    markersize=0,
    figsize=(8, 6),
)

# %%
fig = plotter.plot_chip_feature(
    chip_id=chip_id,
    feature_name=feature_name,
    skip_points=2,
    normalize_to_first=True,
    markersize=0,
    figsize=(8, 6),
)

# %%
fig = plotter.plot_chip_feature(
    chip_id=chip_id,
    feature_name=feature_name,
    skip_points=5,
    normalize_to_first=False,
    markersize=0,
    figsize=(8, 6),
)
# Out:
# 2025-08-31 19:35:33 - chip_feature_plotter - INFO - chip_feature_plotter.py:88 - 开始绘制芯片 20250825001 的特征 absgm_max_forward
# 2025-08-31 19:35:33 - chip_feature_plotter - INFO - chip_feature_plotter.py:96 - 找到 5 个特征文件
# 2025-08-31 19:35:33 - chip_feature_plotter - INFO - chip_feature_plotter.py:138 - 成功加载 5 个设备的数据
# 2025-08-31 19:35:33 - chip_feature_plotter - INFO - chip_feature_plotter.py:234 - 数据处理摘要:
# 2025-08-31 19:35:33 - chip_feature_plotter - INFO - chip_feature_plotter.py:236 -   设备 1: 5001 -> 4996 点
# 2025-08-31 19:35:33 - chip_feature_plotter - INFO - chip_feature_plotter.py:238 -     数据范围: 4.91e-05 ~ 2.52e-03
# 2025-08-31 19:35:33 - chip_feature_plotter - INFO - chip_feature_plotter.py:236 -   设备 2: 5001 -> 4996 点
# 2025-08-31 19:35:33 - chip_feature_plotter - INFO - chip_feature_plotter.py:238 -     数据范围: 4.83e-05 ~ 6.76e-04
# 2025-08-31 19:35:33 - chip_feature_plotter - INFO - chip_feature_plotter.py:236 -   设备 3: 5001 -> 4996 点
# 2025-08-31 19:35:33 - chip_feature_plotter - INFO - chip_feature_plotter.py:238 -     数据范围: 6.16e-05 ~ 1.84e-03
# 2025-08-31 19:35:33 - chip_feature_plotter - INFO - chip_feature_plotter.py:236 -   设备 4: 5001 -> 4996 点
# 2025-08-31 19:35:33 - chip_feature_plotter - INFO - chip_feature_plotter.py:238 -     数据范围: 3.85e-04 ~ 3.86e-03
# 2025-08-31 19:35:33 - chip_feature_plotter - INFO - chip_feature_plotter.py:236 -   设备 5: 5001 -> 4996 点
# 2025-08-31 19:35:33 - chip_feature_plotter - INFO - chip_feature_plotter.py:238 -     数据范围: 4.47e-05 ~ 6.47e-03

# %%
fig = plotter.plot_chip_feature(
    chip_id=chip_id,
    feature_name=feature_name,
    skip_points=5,
    normalize_to_first=True,
    markersize=0,
    figsize=(8, 6),
)

# %%
fig = plotter.plot_chip_feature(
    chip_id=chip_id,
    feature_name=feature_name,
    skip_points=10,
    normalize_to_first=True,
    markersize=0,
    figsize=(8, 6),
)

# %%
fig = plotter.plot_chip_feature(
    chip_id=chip_id,
    feature_name=feature_name,
    skip_points=20,
    normalize_to_first=True,
    markersize=0,
    figsize=(8, 6),
)

# %%
fig = plotter.plot_chip_feature(
    chip_id=chip_id,
    feature_name=feature_name,
    skip_points=50,
    normalize_to_first=True,
    markersize=0,
    figsize=(8, 6),
)

# %%
fig = plotter.plot_chip_feature(
    chip_id=chip_id,
    feature_name=feature_name,
    skip_points=100,
    normalize_to_first=True,
    markersize=0,
    figsize=(8, 6),
)

# %%
fig = plotter.plot_chip_feature(
    chip_id=chip_id,
    feature_name=feature_name,
    skip_points=200,
    normalize_to_first=True,
    markersize=0,
    figsize=(8, 6),
)

# %%
fig = plotter.plot_chip_feature(
    chip_id=chip_id,
    feature_name=feature_name,
    skip_points=200,
    normalize_to_first=False,
    markersize=0,
    figsize=(8, 6),
)
